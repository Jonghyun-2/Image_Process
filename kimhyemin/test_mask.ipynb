# %%
#mask
import cv2
import numpy as np
from matplotlib import pyplot as plt

sample = cv2.imread('sample.png',cv2.IMREAD_GRAYSCALE)
ret, img = cv2.threshold(sample, 125, 255, cv2.THRESH_BINARY) 
#ret, img_result2 = cv2.threshold(sample, 0, 255, cv2.THRESH_BINARY+cv2.THRESH_OTSU)

mask = np.zeros(img.shape[:2],np.uint8)
mask[100:600,30:730] = 255

img2 = cv2.bitwise_and(img,img,mask=mask)

print("masked_img : ", masked_img.shape[:2])

plt.figure(figsize=(20, 10)) 

plt.subplot(121),plt.imshow(mask,'gray'),plt.title('Mask'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(img2,'gray'),plt.title('Masked Image'), plt.xticks([]), plt.yticks([])

plt.show()
# Out:
# masked_img :  (616, 766)

# %%
#cropping
import cv2
import numpy as np
import matplotlib.pyplot as plt


img = cv2.imread('sample.png',cv2.IMREAD_GRAYSCALE)
ret, imgc = cv2.threshold(img, 125, 255, cv2.THRESH_BINARY)
#ret, img_result2 = cv2.threshold(img, 0, 255, cv2.THRESH_BINARY+cv2.THRESH_OTSU)

cropping = imgc[100:600,30:730] 

cv2.imshow("cropping",cropping)
cv2.waitKey(0)
cv2.destroyAllWindows()
